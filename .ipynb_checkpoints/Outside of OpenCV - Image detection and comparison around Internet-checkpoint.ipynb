# %% [markdown]
# ## Porównanie zdjęć metodą SSIM
# * źródło - https://www.pyimagesearch.com/2014/09/15/python-compare-two-images/
# Porównanie zdjęcia pokoju, zmodyfikowanego zdjęcia pokoju oraz dwóch innych pokojów z pomocą SSIM
# Zasada działania SSIM -

# %% [markdown]
# Wykorzystując kod z podanego źródła porównałem zdjęcia pokoi metodą MSE i SSIM. W ogólności podobieństwo jest wyliczane średnią kwadratową różnicę między intensywnością pikseli. Metoda MSE jest prostsza i mniej dokładna, natomiast SSIM bierze pod uwagę słabości MSE i poprawia jakość porównywania.

# %%
from skimage import measure
import matplotlib.pyplot as plt
import numpy as np
import cv2

plt.rcParams["figure.figsize"] = (50,20)

def mse(imageA, imageB):
    # the 'Mean Squared Error' between the two images is the
    # sum of the squared difference between the two images;
    # NOTE: the two images must have the same dimension
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])

    # return the MSE, the lower the error, the more "similar"
    # the two images are
    return err
 
def compare_images(imageA, imageB, title):
    # compute the mean squared error and structural similarity
    # index for the images
    m = measure.compare_mse(imageA, imageB)
    #s = ssim(imageA, imageB)
    s = measure.compare_ssim(imageA, imageB)
 
    # setup the figure
    fig = plt.figure(title)
    plt.suptitle("MSE: %.2f, SSIM: %.2f" % (m, s),fontsize = 50)
 
    # show first image
    ax = fig.add_subplot(1, 2, 1)
    plt.imshow(imageA, cmap = plt.cm.gray)
    plt.axis("off")

    # show the second image
    ax = fig.add_subplot(1, 2, 2)
    plt.imshow(imageB, cmap = plt.cm.gray)
    plt.axis("off")
 
    # show the images
    plt.show()

# load the images -- the original, the original + contrast,
# and the original + photoshop
original = cv2.imread("compr1.jpg")
contrast = cv2.imread("compr1v2.jpg")
shopped = cv2.imread("compr2.jpg")
 
# convert the images to grayscale
original = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
contrast = cv2.cvtColor(contrast, cv2.COLOR_BGR2GRAY)
shopped = cv2.cvtColor(shopped, cv2.COLOR_BGR2GRAY)

# initialize the figure
fig = plt.figure("Images")
images = ("Original", original), ("Contrast", contrast), ("Photoshopped", shopped)
 
# loop over the images
for (i, (name, image)) in enumerate(images):
    # show the image
    ax = fig.add_subplot(1, 3, i + 1)
    ax.set_title(name)
    plt.imshow(image, cmap = plt.cm.gray)
    plt.axis("off")
 
# show the figure
plt.show()
 
# compare the images
compare_images(original, original, "Original vs. Original")
compare_images(original, contrast, "Original vs. Contrast")
compare_images(original, shopped, "Original vs. Photoshopped")

# %% [markdown]
# Porównanie zdjęcia z jego rozmytą wersją

# %%
original = cv2.imread("compr1.jpg")
blr = cv2.imread("compr1blr.jpg")
original = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
blr = cv2.cvtColor(blr, cv2.COLOR_BGR2GRAY)

compare_images(original, blr, "Original vs. Contrast")

# %% [markdown]
# Jest to mało restrykcyjna metoda
